# %% [markdown]
# ### Layers

# %%
inventory = gpd.read_file('inventory.shp')

# %%
# classifier 1
# classifier 2
# age
# temperature
plt.show()

# %%
df = pd.read_csv('/content/yield.csv')

# %%
# Yields
# Out:
#   Classifier1  Classifier2                        AIDBSPP  0  10   20   30  \
# 0          BF            7                   Poplar/aspen  0   0  1.2  5.9
# 1          BP            5                     Balsam fir  0   0  0.0  0.0
# 2          BP            6  Subalpine fir (or alpine fir)  0   0  0.0  0.0
# 3          BS            5                        Hemlock  0   0  0.0  0.1
# 4          GA            8               Mountain hemlock  0   0  0.0  0.1
# 5          JP            6                 Whitebark pine  0   0  0.0  0.0
# 6          TA            5                 Lodgepole pine  0   0  0.0  0.0
# 7          TA            7                         Spruce  0   0  0.0  0.0
# 8          WB            7                         Spruce  0   0  0.0  0.0
# 9          WS            6                   Poplar/aspen  0   0  0.0  1.2
#
#      40    50     60  ...    260    270    280    290    300    310    320  \
# ...

# %%
disturbance = gpd.read_file('disturbances.shp', encoding='ISO-8859-1')

# %%
# Disturbances by year
plt.show()

# %% [markdown]
# ### Simulation results

# %%
# NBP
plt.show()

# %%
# Total Biomass C
plt.show()

# %%
# Total Emissions
plt.show()

# %%
# Total Ecosystem C
plt.show()

# %%
conn = sqlite3.connect("compiled_gcbm_output.db")

# %%
# NPP, NEP, NBP
plt.show()

# %%
# Stock change indicator density
plt.show()
# Out:
#       Annual Litterfall  Annual Mortality  Deadwood to Atmosphere  \
# year
# 2010           0.000494          0.000179                0.000640
# 2011           0.000502          0.000181                0.001687
# 2012           0.000312          0.000119                0.001364
# 2013           0.000238          0.000076                0.001241
# 2014           0.000209          0.000050                0.000869
# 2015           0.000158          0.000042                0.001547
# 2016           0.000165          0.000039                0.000858
# 2017           0.000183          0.000040                0.000735
# 2018           0.000196          0.000041                0.000695
# 2019           0.000210          0.000042                0.000656
# 2020           0.000223          0.000044                0.000620
#
#       Decomposition Releases, Rh  Delta Total Biomass  Delta Total DOM  \
# year
# 2010                    0.001155             0.000182        -0.000482
# ...
