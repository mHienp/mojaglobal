# %%
import rasterio as rst
from rasterio.plot import show
from rasterio.mask import mask
from rasterio.windows import Window, from_bounds

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
rst_Dead_Organic_Matter_C_1990 = r'Dead_Organic_Matter_C_1990.tif'
img_Dead_Organic_Matter_C_1990 = rst.open(rst_Dead_Organic_Matter_C_1990)
show(img_Dead_Organic_Matter_C_1990)
# Out:
# <AxesSubplot:>

# %%
rst_NPP_1990 = r'NPP_1990.tif'
img_NPP_1990 = rst.open(rst_NPP_1990)
show(img_NPP_1990)
# Out:
# <AxesSubplot:>

# %%
rst_Bio_To_DOM_From_Disturbances_1992 = r'Bio_To_DOM_From_Disturbances_1992.tif'
img_Bio_To_DOM_From_Disturbances_1992 = rst.open(rst_Bio_To_DOM_From_Disturbances_1992)
show(img_Bio_To_DOM_From_Disturbances_1992)
# Out:
# <AxesSubplot:>

# %%
rst_AG_Biomass_C_1990 = r'AG_Biomass_C_1990.tif'
img_AG_Biomass_C_1990 = rst.open(rst_AG_Biomass_C_1990)
show(img_AG_Biomass_C_1990)
# Out:
# <AxesSubplot:>

# %%
rst_Age_2014 = r'Age_2014.tif'
img_Age_2014 = rst.open(rst_Age_2014)
show(img_Age_2014)
# Out:
# <AxesSubplot:>

# %%
rst_Decomp_Releases_2010 = r'Decomp_Releases_2010.tif'
img_Decomp_Releases_2010 = rst.open(rst_Decomp_Releases_2010)
show(img_Decomp_Releases_2010)
# Out:
# <AxesSubplot:>

# %%
rst_Delta_Total_Biomass_2020 = r'Delta_Total_Biomass_2020.tif'
img_Delta_Total_Biomass_2020 = rst.open(rst_Delta_Total_Biomass_2020)
show(img_Delta_Total_Biomass_2020)
# Out:
# <AxesSubplot:>

# %%
rst_Delta_Total_DOM_2014 = r'Delta_Total_DOM_2014.tif'
img_Delta_Total_DOM_2014 = rst.open(rst_Delta_Total_DOM_2014)
show(img_Delta_Total_DOM_2014)
# Out:
# <AxesSubplot:>

# %%
rst_Delta_Total_Ecosystem_2010 = r'Delta_Total_Ecosystem_2010.tif'
img_Delta_Total_Ecosystem_2010 = rst.open(rst_Delta_Total_Ecosystem_2010)
show(img_Delta_Total_Ecosystem_2010)
# Out:
# <AxesSubplot:>

# %%
rst_Ecosystem_Removals_2015 = r'Ecosystem_Removals_2015.tif'
img_Ecosystem_Removals_2015 = rst.open(rst_Ecosystem_Removals_2015)
show(img_Ecosystem_Removals_2015)
# Out:
# <AxesSubplot:>

# %%
rst_NBP_2019 = r'NBP_2019.tif'
img_NBP_2019 = rst.open(rst_NBP_2019)
show(img_NBP_2019)
# Out:
# <AxesSubplot:>

# %%
rst_NEP_2016 = r'NEP_2016.tif'
img_NEP_2016 = rst.open(rst_NEP_2016)
show(img_NEP_2016)
# Out:
# <AxesSubplot:>

# %%
rst_NPP_1992 = r'NPP_1992.tif'
img_NPP_1992 = rst.open(rst_NPP_1992)
show(img_NPP_1992)
# Out:
# <AxesSubplot:>

# %%
rst_Soil_C_2015 = r'Soil_C_2015.tif'
img_Soil_C_2015 = rst.open(rst_Soil_C_2015)
show(img_Soil_C_2015)
# Out:
# <AxesSubplot:>

# %%
rst_Total_Biomass_C_2013 = r'Total_Biomass_C_2013.tif'
img_Total_Biomass_C_2013 = rst.open(rst_Total_Biomass_C_2013)
show(img_Total_Biomass_C_2013)
# Out:
# <AxesSubplot:>

# %%
rst_Total_Biomass_Emissions_2010 = r'Total_Biomass_Emissions_2010.tif'
img_Total_Biomass_Emissions_2010 = rst.open(rst_Total_Biomass_Emissions_2010)
show(img_Total_Biomass_Emissions_2010)
# Out:
# <AxesSubplot:>

# %%
rst_Total_CH4_Emissions_2017 = r'Total_CH4_Emissions_2017.tif'
img_Total_CH4_Emissions_2017 = rst.open(rst_Total_CH4_Emissions_2017)
show(img_Total_CH4_Emissions_2017)
# Out:
# <AxesSubplot:>

# %%
rst_Total_CO_Emissions_2020 = r'Total_CO_Emissions_2020.tif'
img_Total_CO_Emissions_2020 = rst.open(rst_Total_CO_Emissions_2020)
show(img_Total_CO_Emissions_2020)
# Out:
# <AxesSubplot:>

# %%
rst_Total_DOM_Emissions_2018 = r'Total_DOM_Emissions_2018.tif'
img_Total_DOM_Emissions_2018 = rst.open(rst_Total_DOM_Emissions_2018)
show(img_Total_DOM_Emissions_2018)
# Out:
# <AxesSubplot:>

# %%
rst_Total_Ecosystem_C_2014 = r'Total_Ecosystem_C_2014.tif'
img_Total_Ecosystem_C_2014 = rst.open(rst_Total_Ecosystem_C_2014)
show(img_Total_Ecosystem_C_2014)
# Out:
# <AxesSubplot:>

# %%
rst_Total_Emissions_2013 = r'Total_Emissions_2013.tif'
img_Total_Emissions_2013 = rst.open(rst_Total_Emissions_2013)
show(img_Total_Emissions_2013)
# Out:
# <AxesSubplot:>
